# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_moods.csv')
df.head()
# Out:
#                                           name                        album  \
# 0                                         1999                         1999
# 1                                           23                           23
# 2                                     9 Crimes                            9
# 3                               99 Luftballons               99 Luftballons
# 4  A Boy Brushed Red Living In Black And White  They're Only Chasing Safety
#
#            artist                      id release_date  popularity  length  \
# 0          Prince  2H7PHVdQ3mXqEHXcvclTB0   1982-10-27          68  379266
# 1  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP   2007-04-16          43  318800
# 2     Damien Rice  5GZEeowhvSieFDiR8fQ2im   2006-11-06          60  217946
# 3            Nena  6HA97v4wEGQ5TUClRM0XLc   1984-08-21           2  233000
# 4       Underoath  47IWLfIKOKhFnz1FUEUIkE   2004-01-01          60  268000
#
#    danceability  acousticness  energy  instrumentalness  liveness  valence  \
# 0         0.866       0.13700   0.730          0.000000    0.0843    0.625
# 1         0.381       0.01890   0.832          0.196000    0.1530    0.166
# 2         0.346       0.91300   0.139          0.000077    0.0934    0.116
# 3         0.466       0.08900   0.438          0.000006    0.1130    0.587
# 4         0.419       0.00171   0.932          0.000000    0.1370    0.445
#
#    loudness  speechiness    tempo  key  time_signature       mood
# 0    -8.201       0.0767  118.523    5               4      Happy
# 1    -5.069       0.0492  120.255    8               4        Sad
# 2   -15.326       0.0321  136.168    0               4        Sad
# 3   -12.858       0.0608  193.100    4               4      Happy
# 4    -3.604       0.1060  169.881    1               4  Energetic

# %%
df.shape
# Out:
# (686, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 686 entries, 0 to 685
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              686 non-null    object
#  1   album             686 non-null    object
#  2   artist            686 non-null    object
#  3   id                686 non-null    object
#  4   release_date      686 non-null    object
#  5   popularity        686 non-null    int64
#  6   length            686 non-null    int64
#  7   danceability      686 non-null    float64
#  8   acousticness      686 non-null    float64
#  9   energy            686 non-null    float64
#  10  instrumentalness  686 non-null    float64
#  11  liveness          686 non-null    float64
#  12  valence           686 non-null    float64
#  13  loudness          686 non-null    float64
#  14  speechiness       686 non-null    float64
#  15  tempo             686 non-null    float64
#  16  key               686 non-null    int64
#  17  time_signature    686 non-null    int64
#  18  mood              686 non-null    object
# dtypes: float64(9), int64(4), object(6)
# memory usage: 102.0+ KB

# %%
df['length'].mean()
# Out:
# 221791.48542274052

# %%
df['length'].median()
# Out:
# 213273.0

# %%
df['tempo'].mode()
# Out:
# 0    119.977
# Name: tempo, dtype: float64

# %%
df['tempo'].mode()[0]
# Out:
# 119.977

# %%
df['tempo'].value_counts()
# Out:
# 119.977    3
# 126.000    2
# 126.013    2
# 132.106    2
# 94.003     2
#           ..
# 95.705     1
# 125.603    1
# 125.948    1
# 105.196    1
# 140.179    1
# Name: tempo, Length: 673, dtype: int64

# %% [markdown]
# Range

# %%
df['length'].max()-df['length'].min()
# Out:
# 441600

# %% [markdown]
# IQR

# %%
 df['length'].quantile(0.75)-df['length'].quantile(0.25)
# Out:
# 75455.25

# %%
df['length'].var()
# Out:
# 4019440617.724605

# %%
df['length'].std()
# Out:
# 63399.05849241458

# %%
df.describe(include='all')
# Out:
#         name                                    album           artist  \
# count    686                                      686              686
# unique   686                                      661              540
# top     1999  The Sickness (10th Anniversary Edition)  Various Artists
# freq       1                                        2                9
# mean     NaN                                      NaN              NaN
# std      NaN                                      NaN              NaN
# min      NaN                                      NaN              NaN
# 25%      NaN                                      NaN              NaN
# 50%      NaN                                      NaN              NaN
# 75%      NaN                                      NaN              NaN
# max      NaN                                      NaN              NaN
#
#                             id release_date  popularity         length  \
# count                      686          686  686.000000     686.000000
# unique                     686          450         NaN            NaN
# top     2H7PHVdQ3mXqEHXcvclTB0   2020-05-01         NaN            NaN
# freq                         1            8         NaN            NaN
# mean                       NaN          NaN   41.534985  221791.485423
# std                        NaN          NaN   23.045707   63399.058492
# min                        NaN          NaN    0.000000   76773.000000
# 25%                        NaN          NaN   30.000000  179114.500000
# 50%                        NaN          NaN   47.000000  213273.000000
# 75%                        NaN          NaN   57.000000  254569.750000
# max                        NaN          NaN   88.000000  518373.000000
#
#         danceability  acousticness      energy  instrumentalness    liveness  \
# count     686.000000    686.000000  686.000000        686.000000  686.000000
# unique           NaN           NaN         NaN               NaN         NaN
# top              NaN           NaN         NaN               NaN         NaN
# freq             NaN           NaN         NaN               NaN         NaN
# mean        0.500553      0.449749    0.507693          0.349610    0.166867
# std         0.158955      0.410729    0.326490          0.410517    0.142128
# min         0.078900      0.000005    0.001290          0.000000    0.031800
# 25%         0.388000      0.014825    0.202000          0.000034    0.092500
# 50%         0.505000      0.359000    0.495500          0.026350    0.111000
# 75%         0.612000      0.905750    0.844000          0.858250    0.173750
# max         0.941000      0.996000    0.994000          0.966000    0.963000
#
#            valence    loudness  speechiness       tempo         key  \
# count   686.000000  686.000000   686.000000  686.000000  686.000000
# unique         NaN         NaN          NaN         NaN         NaN
# top            NaN         NaN          NaN         NaN         NaN
# freq           NaN         NaN          NaN         NaN         NaN
# mean      0.342438  -11.531020     0.053946  119.134679    5.335277
# std       0.252304    7.468629     0.041374   28.978685    3.550858
# min       0.035300  -42.018000     0.023200   50.960000    0.000000
# 25%       0.131250  -15.858750     0.033200   99.008750    2.000000
# 50%       0.282000   -9.358000     0.040700  120.071000    6.000000
# 75%       0.508750   -5.634500     0.057375  132.953250    9.000000
# max       0.977000    1.342000     0.416000  217.950000   11.000000
#
#         time_signature mood
# count       686.000000  686
# unique             NaN    4
# top                NaN  Sad
# freq               NaN  197
# mean          3.870262  NaN
# std           0.500297  NaN
# min           1.000000  NaN
# 25%           4.000000  NaN
# 50%           4.000000  NaN
# 75%           4.000000  NaN
# max           5.000000  NaN

# %%
df['length'].describe()
# Out:
# count       686.000000
# mean     221791.485423
# std       63399.058492
# min       76773.000000
# 25%      179114.500000
# 50%      213273.000000
# 75%      254569.750000
# max      518373.000000
# Name: length, dtype: float64

# %%
df.skew()
# Out:
# <ipython-input-20-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# popularity         -0.457654
# length              1.214469
# danceability       -0.029141
# acousticness        0.150749
# energy             -0.010979
# instrumentalness    0.475735
# liveness            2.739963
# valence             0.767037
# loudness           -1.053219
# speechiness         4.341099
# tempo               0.360149
# key                -0.044707
# time_signature     -3.610186
# dtype: float64

# %%
df.kurt()
# Out:
# <ipython-input-21-8bd0d54cd88d>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.kurt()
# popularity          -0.568316
# length               2.800352
# danceability        -0.272376
# acousticness        -1.741088
# energy              -1.458141
# instrumentalness    -1.658068
# liveness             8.499941
# valence             -0.417698
# loudness             0.560436
# speechiness         25.998966
# tempo                0.166731
# key                 -1.266498
# time_signature      17.420626
# dtype: float64

# %%
df['length'].kurt()
# Out:
# 2.800352276486072

# %%
df.corr()
# Out:
# <ipython-input-23-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   popularity    length  danceability  acousticness    energy  \
# popularity          1.000000 -0.086197      0.134086     -0.039792  0.056923
# length             -0.086197  1.000000     -0.041378     -0.165689  0.116968
# danceability        0.134086 -0.041378      1.000000     -0.324908  0.332579
# acousticness       -0.039792 -0.165689     -0.324908      1.000000 -0.902001
# energy              0.056923  0.116968      0.332579     -0.902001  1.000000
# instrumentalness   -0.125816 -0.165860     -0.292267      0.578946 -0.591110
# liveness            0.034065 -0.044103      0.105590     -0.289672  0.341227
# valence             0.054375  0.003923      0.526196     -0.495770  0.528810
# loudness            0.100066  0.182840      0.350843     -0.790299  0.854015
# speechiness         0.056608 -0.060854      0.115579     -0.285138  0.342475
# tempo               0.016300  0.007995     -0.031581     -0.285407  0.318882
# key                -0.080725  0.034683     -0.001598      0.055456 -0.051011
# time_signature      0.095547  0.021997      0.100803     -0.184460  0.183390
#
#                   instrumentalness  liveness   valence  loudness  speechiness  \
# popularity               -0.125816  0.034065  0.054375  0.100066     0.056608
# length                   -0.165860 -0.044103  0.003923  0.182840    -0.060854
# danceability             -0.292267  0.105590  0.526196  0.350843     0.115579
# acousticness              0.578946 -0.289672 -0.495770 -0.790299    -0.285138
# energy                   -0.591110  0.341227  0.528810  0.854015     0.342475
# instrumentalness          1.000000 -0.203588 -0.493577 -0.713969    -0.243862
# liveness                 -0.203588  1.000000  0.166171  0.269900     0.244812
# valence                  -0.493577  0.166171  1.000000  0.433263     0.176182
# loudness                 -0.713969  0.269900  0.433263  1.000000     0.245819
# speechiness              -0.243862  0.244812  0.176182  0.245819     1.000000
# tempo                    -0.221368  0.127330  0.130014  0.285813     0.112973
# key                       0.024498 -0.013686 -0.042879 -0.027717     0.029047
# time_signature           -0.155669  0.010085  0.138277  0.216719     0.034263
#
#                      tempo       key  time_signature
# popularity        0.016300 -0.080725        0.095547
# length            0.007995  0.034683        0.021997
# danceability     -0.031581 -0.001598        0.100803
# acousticness     -0.285407  0.055456       -0.184460
# energy            0.318882 -0.051011        0.183390
# instrumentalness -0.221368  0.024498       -0.155669
# liveness          0.127330 -0.013686        0.010085
# valence           0.130014 -0.042879        0.138277
# loudness          0.285813 -0.027717        0.216719
# speechiness       0.112973  0.029047        0.034263
# tempo             1.000000 -0.078653        0.066568
# key              -0.078653  1.000000        0.008086
# time_signature    0.066568  0.008086        1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# <ipython-input-24-f6412ee67fb3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
df.cov()
# Out:
# <ipython-input-25-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                      popularity        length  danceability  acousticness  \
# popularity           531.104614 -1.259408e+05      0.491186     -0.376653
# length           -125940.825037  4.019441e+09   -416.993876  -4314.510909
# danceability           0.491186 -4.169939e+02      0.025267     -0.021212
# acousticness          -0.376653 -4.314511e+03     -0.021212      0.168699
# energy                 0.428298  2.421134e+03      0.017260     -0.120958
# instrumentalness      -1.190307 -4.316741e+03     -0.019071      0.097617
# liveness               0.111577 -3.974046e+02      0.002385     -0.016910
# valence                0.316166  6.274432e+01      0.021103     -0.051376
# loudness              17.223398  8.657531e+04      0.416511     -2.424309
# speechiness            0.053976 -1.596247e+02      0.000760     -0.004845
# tempo                 10.885988  1.468904e+04     -0.145469     -3.397026
# key                   -6.605908  7.807866e+03     -0.000902      0.080879
# time_signature         1.101626  6.977054e+02      0.008016     -0.037904
#
#                        energy  instrumentalness    liveness    valence  \
# popularity           0.428298         -1.190307    0.111577   0.316166
# length            2421.133501      -4316.741151 -397.404561  62.744324
# danceability         0.017260         -0.019071    0.002385   0.021103
# acousticness        -0.120958          0.097617   -0.016910  -0.051376
# energy               0.106596         -0.079226    0.015834   0.043561
# instrumentalness    -0.079226          0.168525   -0.011879  -0.051122
# liveness             0.015834         -0.011879    0.020200   0.005959
# valence              0.043561         -0.051122    0.005959   0.063657
# loudness             2.082457         -2.189031    0.286498   0.816426
# speechiness          0.004626         -0.004142    0.001440   0.001839
# tempo                3.017025         -2.633444    0.524431   0.950589
# key                 -0.059139          0.035711   -0.006907  -0.038415
# time_signature       0.029955         -0.031971    0.000717   0.017454
#
#                       loudness  speechiness         tempo          key  \
# popularity           17.223398     0.053976     10.885988    -6.605908
# length            86575.309744  -159.624735  14689.038397  7807.866208
# danceability          0.416511     0.000760     -0.145469    -0.000902
# acousticness         -2.424309    -0.004845     -3.397026     0.080879
# energy                2.082457     0.004626      3.017025    -0.059139
# instrumentalness     -2.189031    -0.004142     -2.633444     0.035711
# liveness              0.286498     0.001440      0.524431    -0.006907
# valence               0.816426     0.001839      0.950589    -0.038415
# loudness             55.780414     0.075960     61.858798    -0.735043
# speechiness           0.075960     0.001712      0.135450     0.004267
# tempo                61.858798     0.135450    839.764199    -8.093323
# key                  -0.735043     0.004267     -8.093323    12.608593
# time_signature        0.809778     0.000709      0.965100     0.014364
#
#                   time_signature
# popularity              1.101626
# length                697.705405
# danceability            0.008016
# acousticness           -0.037904
# energy                  0.029955
# instrumentalness       -0.031971
# liveness                0.000717
# valence                 0.017454
# loudness                0.809778
# speechiness             0.000709
# tempo                   0.965100
# key                     0.014364
# time_signature          0.250297

# %%
df['length'].var()
# Out:
# 4019440617.724605

# %%
sns.heatmap(df.cov(),annot=True)
plt.show()
# Out:
# <ipython-input-29-3653ad630287>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.cov(),annot=True)

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# <ipython-input-31-f6412ee67fb3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
